# %%
import pandas as pd
data = 'C:/Users/Blanca/Dropbox/My PC (Blanca)/Desktop/DSDM/brushup_files/data/WB_pop_clean.csv'
df = pd.read_csv(data)
df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code      2001  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  19688632
# 1  Population, total  SP.POP.TOTL         Albania          ALB   3060173
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  31200985
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     58324
# 4  Population, total  SP.POP.TOTL         Andorra          AND     67820
#
#        2002      2003      2011      2012      2013      2021      2022  \
# 0  21000256  22645130  29249157  30466479  31541209  40099462  41128771
# 1   3051010   3039616   2905195   2900401   2895092   2811666   2777689
# 2  31624696  32055883  36543541  37260563  38000626  44177969  44903225
# 3     58177     57941     54310     53691     52995     45035     44273
# 4     70849     73907     70567     71013     71367     79034     79824
#
#        2023
# 0  42239854
# 1   2745972
# 2  45606480
# 3     43914
# 4     80088

# %%
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   218 non-null    object
#  1   Series Code   218 non-null    object
#  2   Country Name  218 non-null    object
#  3   Country Code  218 non-null    object
#  4   2001          218 non-null    int64
#  5   2002          218 non-null    int64
#  6   2003          218 non-null    int64
#  7   2011          218 non-null    int64
#  8   2012          218 non-null    int64
#  9   2013          218 non-null    int64
#  10  2021          218 non-null    int64
#  11  2022          218 non-null    int64
#  12  2023          218 non-null    int64
# dtypes: int64(9), object(4)
# memory usage: 22.3+ KB

# %%
df.describe()
# Out:
#                2001          2002          2003          2011          2012  \
# count  2.180000e+02  2.180000e+02  2.180000e+02  2.180000e+02  2.180000e+02
# mean   5.702126e+07  5.777115e+07  5.851666e+07  6.460916e+07  6.541101e+07
# std    4.357249e+08  4.413970e+08  4.470272e+08  4.927859e+08  4.988148e+08
# min    9.621000e+03  9.609000e+03  9.668000e+03  1.028300e+04  1.044400e+04
# 25%    6.252495e+05  6.425825e+05  6.631015e+05  7.210558e+05  7.268502e+05
# 50%    5.175659e+06  5.267269e+06  5.352080e+06  5.893246e+06  5.896596e+06
# 75%    1.716950e+07  1.764196e+07  1.812237e+07  2.214575e+07  2.245686e+07
# max    6.226487e+09  6.308285e+09  6.389593e+09  7.053989e+09  7.141431e+09
#
#                2013          2021          2022          2023
# count  2.180000e+02  2.180000e+02  2.180000e+02  2.180000e+02
# mean   6.621822e+07  7.226807e+07  7.284406e+07  7.351661e+07
# std    5.048778e+08  5.500182e+08  5.542406e+08  5.591759e+08
# ...

# %%
years = ['2001','2002','2003','2011','2012','2013','2021','2022','2023']
years_max = df[years].max()
years_min = df[years].min()

print('maximums: \n ', years_max)
print('minimums: \n ', years_min)
# Out:
# maximums:
#   2001    6226487141
# 2002    6308284566
# 2003    6389592840
# 2011    7053988749
# 2012    7141430933
# 2013    7229458453
# 2021    7888963821
# 2022    7951595433
# 2023    8024997028
# dtype: int64
# minimums:
#   2001     9621
# 2002     9609
# 2003     9668
# 2011    10283
# 2012    10444
# 2013    10694
# 2021    11204
# 2022    11312
# 2023    11396
# dtype: int64

# %%
print(df.index[df['Country Name'] == 'Spain'])
print(df.index[df['Country Name'] == 'Chile'])
print(df.index[df['Country Name'] == 'Iceland'])
print(df.index[df['Country Name'] == 'Japan'])
# Out:
# Index([179], dtype='int64')
# Index([40], dtype='int64')
# Index([88], dtype='int64')
# Index([98], dtype='int64')

# %%
new_df = df.loc[df['Country Name'].isin(['Chile', 'Spain'])].reset_index()
new_df
# Out:
#    index        Series Name  Series Code Country Name Country Code      2001  \
# 0     40  Population, total  SP.POP.TOTL        Chile          CHL  15523978
# 1    179  Population, total  SP.POP.TOTL        Spain          ESP  40850412
#
#        2002      2003      2011      2012      2013      2021      2022  \
# 0  15693790  15859112  17173573  17341771  17509925  19493184  19603733
# 1  41431558  42187645  46742697  46773055  46620045  47415794  47778340
#
#        2023
# 0  19629590
# 1  48373336

# %%
df.dtypes
# Out:
# Series Name     object
# Series Code     object
# Country Name    object
# Country Code    object
# 2001             int64
# 2002             int64
# 2003             int64
# 2011             int64
# 2012             int64
# 2013             int64
# 2021             int64
# 2022             int64
# 2023             int64
# dtype: object

# %%
Q1 = df['2001'].quantile(0.25)
Q3 = df['2001'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['2001'] < Q1 - 1.5*IQR) | (df['2001'] > Q3 + 1.5*IQR)]
outliers
# Out:
#            Series Name  Series Code        Country Name Country Code  \
# 15   Population, total  SP.POP.TOTL          Bangladesh          BGD
# 26   Population, total  SP.POP.TOTL              Brazil          BRA
# 41   Population, total  SP.POP.TOTL               China          CHN
# 44   Population, total  SP.POP.TOTL    Congo, Dem. Rep.          COD
# 58   Population, total  SP.POP.TOTL    Egypt, Arab Rep.          EGY
# 64   Population, total  SP.POP.TOTL            Ethiopia          ETH
# 68   Population, total  SP.POP.TOTL              France          FRA
# 73   Population, total  SP.POP.TOTL             Germany          DEU
# 89   Population, total  SP.POP.TOTL               India          IND
# 90   Population, total  SP.POP.TOTL           Indonesia          IDN
# 91   Population, total  SP.POP.TOTL  Iran, Islamic Rep.          IRN
# 96   Population, total  SP.POP.TOTL               Italy          ITA
# 98   Population, total  SP.POP.TOTL               Japan          JPN
# ...

# %%
outliers.shape
# Out:
# (28, 13)

# %%
df2 = df.drop(outliers.index)
df2.sample(4)
# Out:
#            Series Name  Series Code Country Name Country Code      2001  \
# 178  Population, total  SP.POP.TOTL  South Sudan          SSD   6394431
# 156  Population, total  SP.POP.TOTL       Poland          POL  38248076
# 9    Population, total  SP.POP.TOTL        Aruba          ABW     90691
# 169  Population, total  SP.POP.TOTL   Seychelles          SYC     81202
#
#          2002      2003      2011      2012      2013      2021      2022  \
# 178   6686100   6992367  10243050  10701604  11106031  10748272  10913164
# 156  38230364  38204570  38063255  38063164  38040196  37747124  36821749
# 9       91781     92701    101288    102112    102880    106537    106445
# 169     83723     82781     87441     88303     89949     99258    119878
#
#          2023
# 178  11088796
# 156  36685849
# 9      106277
# 169    119773

# %%
df2.shape
# Out:
# (190, 13)
